# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sasa-leaf/janken-online-predictor/blob/master/main.ipynb)

# %%
TOKEN = "あなたのngrokトークンを貼り付けてください"

# %%
# リポジトリのクローン
# !git clone https://github.com/sasa-leaf/janken-online-predictor.git
# %cd janken-online-predictor

# %%
# 必要パッケージのインストール
# !pip install japanize-matplotlib -q

# %%
# ngrokトークンの設定
import os
from pyngrok import ngrok

os.environ["NGROK_TOKEN"] = TOKEN
ngrok.set_auth_token(os.environ["NGROK_TOKEN"])

# %%
# サーバーの起動
# !python main.py
